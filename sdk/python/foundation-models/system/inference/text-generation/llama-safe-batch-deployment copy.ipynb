# %% [markdown]
# # How to create an Azure AI Content Safety enabled Llama batch endpoint (Preview)
# ### This notebook will walk you through the steps to create an __Azure AI Content Safety__ enabled __Llama__ batch endpoint.
# ### This notebook is under preview
# ### The steps are:
# 1. Create an __Azure AI Content Safety__ resource for moderating the request from user and response from the __Llama__ batch endpoint.
# 2. Create a new __Azure AI Content Safety__ enabled __Llama__ batch endpoint with a custom score.py which will integrate with the __Azure AI Content Safety__ resource to moderate the response from the __Llama__ model and the request from the user, but to make the custom score.py to sucessfully autheticated to the __Azure AI Content Safety__ resource, for batch inferencing is using __Environment variable__ to pass the access key of the __Azure AI Content Safety__ resource to the custom score.py via environment variable, then the custom score.py can use the key directly to access the Azure AI Content Safety resource, this option is less secure than the first option, if someone in your org has access to the endpoint, he/she can get the access key from the environment variable and use it to access the Azure AI Content Safety resource.

# %% [markdown]
# ### 1. Prerequisites
# #### 1.1 Check List:
# - [x] You have created a new Python virtual environment for this notebook.
# - [x] The identity you are using to execute this notebook(yourself or your VM) need to have the __Contributor__ role on the resource group where the AML Workspace your specified is located, because this notebook will create an Azure AI Content Safety resource using that identity.
# - [x] Required If you choose to use the UAI approach, the identity executing this notebook (either yourself or your virtual machine) needs to have the owner role on the resource group that contains the specified AML Workspace. This is because the notebook will create a new UAI and assign the UAI some required roles to successfully create the Azure AI Content Safety enabled Llama endpoint.

# %% [markdown]
# #### 1.2 Assign variables for the workspace and deployment

# %%
# The public registry name contains Llama models
registry_name = "msft-meta-preview"

# Name of the Llama model to be deployed
# available_llama_models_text_generation = ["Llama-2-7b", "Llama-2-13b"]
# available_llama_models_chat_complete = ["Llama-2-7b-chat", "Llama-2-13b-chat"]
model_name = "Llama-2-7b"

endpoint_name = "bani-llama-endpt"  # Replace with your endpoint name
deployment_name = "bani-llama-dep"  # Replace with your deployment name, lower case only!!!
sku_name = "Standard_NC6"  # Name of the sku(instance type) Check the model-list(can be found in the parent folder(inference)) to get the most optimal sku for your model (Default: Standard_DS2_v2)

environment_name = "for-llama-env"  # Replace with your environment name

# %% [markdown]
# #### 1.3 Install Dependencies(as needed)

# %%
# uncomment the following lines to install the required packages
# %pip install azure-identity==1.13.0
# %pip install azure-mgmt-cognitiveservices==13.4.0
# %pip install azure-ai-ml==1.8.0
# %pip install azure-mgmt-msi==7.0.0
# %pip install azure-mgmt-authorization==3.0.0

# %% [markdown]
# #### 1.4 Get credential

# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential

try:
    credential = DefaultAzureCredential()
    # Check if given credential can get token successfully.
    credential.get_token("https://management.azure.com/.default")
except Exception as ex:
    # Fall back to InteractiveBrowserCredential in case DefaultAzureCredential not work
    credential = InteractiveBrowserCredential()

# %% [markdown]
# #### 1.5 Configure workspace

# %%
from azure.ai.ml import MLClient

try:
    ml_client = MLClient.from_config(credential=credential)
except Exception as ex:
    # enter details of your AML workspace
    subscription_id = "b17253fa-f327-42d6-9686-f3e553e24763"
    resource_group = "bani-llm"
    workspace = "bani-llm-ws"

    # get a handle to the workspace
    ml_client = MLClient(credential, subscription_id, resource_group, workspace, logging_enable=True,)


subscription_id = ml_client.subscription_id
resource_group = ml_client.resource_group_name
workspace = ml_client.workspace_name

print(f"Connected to workspace {workspace}")
# Out:
# Connected to workspace bani-llm-ws

# %% [markdown]
# #### 1.6 Assign variables for Azure Content Safety
# Currently, Azure AI Content Safety is in a limited set of regions:
#
#
# __NOTE__: before you choose the region to deploy the Azure AI Content Safety, please be aware that your data will be transferred to the region you choose and by selecting a region outside your current location, you may be allowing the transmission of your data to regions outside your jurisdiction. It is important to note that data protection and privacy laws may vary between jurisdictions. Before proceeding, we strongly advise you to familiarize yourself with the local laws and regulations governing data transfer and ensure that you are legally permitted to transmit your data to an overseas location for processing. By continuing with the selection of a different region, you acknowledge that you have understood and accepted any potential risks associated with such data transmission. Please proceed with caution.

# %%
from azure.mgmt.cognitiveservices import CognitiveServicesManagementClient

acs_client = CognitiveServicesManagementClient(credential, subscription_id)


# settings for the Azure AI Content Safety resource
# we will choose existing AACS resource if it exists, otherwise create a new one
# name of azure ai content safety resource, has to be unique
import time

aacs_name = f"{endpoint_name}-aacs-{str(time.time()).replace('.','')}"
available_aacs_locations = ["east us", "west europe"]

# create a new Cognitive Services Account
kind = "ContentSafety"
aacs_sku_name = "S0"
aacs_location = available_aacs_locations[0]


print("Available SKUs:")
aacs_skus = acs_client.resource_skus.list()
print("SKU Name\tSKU Tier\tLocations")
for sku in aacs_skus:
    if sku.kind == "ContentSafety":
        locations = ",".join(sku.locations)
        print(sku.name + "\t" + sku.tier + "\t" + locations)

print(
    f"Choose a new Azure AI Content Safety resource in {aacs_location} with SKU {aacs_sku_name}"
)

# %% [markdown]
# ### 2. Create Azure AI Content Safety

# %%
from azure.mgmt.cognitiveservices.models import Account, Sku, AccountProperties


parameters = Account(
    sku=Sku(name=aacs_sku_name),
    kind=kind,
    location=aacs_location,
    properties=AccountProperties(
        custom_sub_domain_name=aacs_name, public_network_access="Enabled"
    ),
)
# How many seconds to wait between checking the status of an async operation.
wait_time = 10


def find_acs(accounts):
    return next(
        x
        for x in accounts
        if x.kind == "ContentSafety"
        and x.location == aacs_location
        and x.sku.name == aacs_sku_name
    )


try:
    # check if AACS exists
    aacs = acs_client.accounts.get(resource_group, aacs_name)
    print(f"Found existing Azure AI content safety Account {aacs.name}.")
except:
    try:
        # check if there is an existing AACS resource within same resource group
        aacs = find_acs(acs_client.accounts.list_by_resource_group(resource_group))
        print(
            f"Found existing Azure AI content safety Account {aacs.name} in resource group {resource_group}."
        )
    except:
        print(f"Creating Azure AI content safety Account {aacs_name}.")
        acs_client.accounts.begin_create(resource_group, aacs_name, parameters).wait()
        print("Resource created.")
        aacs = acs_client.accounts.get(resource_group, aacs_name)


aacs_endpoint = aacs.properties.endpoint
aacs_resource_id = aacs.id
print(f"AACS endpoint is {aacs_endpoint}")
print(f"AACS ResourceId is {aacs_resource_id}")

aacs_access_key = acs_client.accounts.list_keys(
    resource_group_name=resource_group, account_name=aacs.name
).key1

# %% [markdown]
# ### 3. Create Azure AI Content Safety enabled Llama batch endpoint

# %% [markdown]
# #### 3.1 Check if Llama model is available in the AML registry.

# %%
reg_client = MLClient(
    credential,
    subscription_id=subscription_id,
    resource_group_name=resource_group,
    registry_name=registry_name,
    logging_enable=True,
)
version_list = list(
    reg_client.models.list(model_name)
)  # list available versions of the model
llama_model = None
if len(version_list) == 0:
    raise Exception(f"No model named {model_name} found in registry")
else:
    model_version = version_list[0].version
    llama_model = reg_client.models.get(model_name, model_version)
    print(
        f"Using model name: {llama_model.name}, version: {llama_model.version}, id: {llama_model.id} for inferencing"
    )
# Out:
# DEBUG:azure.identity._internal.decorators:AzureCliCredential.get_token succeeded
# DEBUG:azure.identity._internal.decorators:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: banide@microsoft.com. Object ID (user): 558795a7-7d0c-4b80-b7c6-8f71e52a8bef
# INFO:azure.identity._credentials.default:DefaultAzureCredential acquired a token from AzureCliCredential
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://eastus.api.azureml.ms/registrymanagement/v1.0/registries/msft-meta-preview/discovery'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json, text/json'
#     'x-ms-client-request-id': '1828ba21-20fe-11ee-90ec-000d3ac5f120'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://eastus.api.azureml.ms/registrymanagement/v1.0/registries/msft-meta-preview/discovery'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json, text/json'
#     'x-ms-client-request-id': '1828ba21-20fe-11ee-90ec-000d3ac5f120'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): eastus.api.azureml.ms:443
# DEBUG:urllib3.connectionpool:https://eastus.api.azureml.ms:443 "GET /registrymanagement/v1.0/registries/msft-meta-preview/discovery HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Wed, 12 Jul 2023 21:50:21 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Date': 'Wed, 12 Jul 2023 21:50:21 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'Accept-Encoding'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus-02'
#     'x-request-time': '0.367'
#     'Content-Encoding': 'gzip'
# Response content:
# {
#   "registryId": "95309365-a102-4a53-a0cd-ce88ddee1d9d",
#   "registryName": "msft-meta-preview",
#   "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#   "primaryRegion": "eastus2",
#   "regions": [
#     "eastus2",
#     "canadaeast",
#     "centralus",
#     "eastus",
#     "eastus2euap",
#     "southcentralus",
#     "westcentralus",
#     "westus",
#     "westus2",
#     "westus3",
#     "australiaeast"
#   ],
#   "subscriptionId": "ed2cab61-14cc-4fb3-ac23-d72609214cfd",
#   "resourceGroup": "fm_demo_meta",
#   "workspaceName": null,
#   "primaryRegionResourceProviderUri": "https://cert-eastus2.experiments.azureml.net/",
#   "registryFqdns": {
#     "eastus2": {
#       "uri": "https://eastus2.api.azureml.ms"
#     },
#     "canadaeast": {
#       "uri": "https://canadaeast.api.azureml.ms"
#     },
#     "centralus": {
#       "uri": "https://centralus.api.azureml.ms"
#     },
#     "eastus": {
#       "uri": "https://eastus.api.azureml.ms"
#     },
#     "eastus2euap": {
#       "uri": "https://eastus2euap.api.azureml.ms"
#     },
#     "southcentralus": {
#       "uri": "https://southcentralus.api.azureml.ms"
#     },
#     "westcentralus": {
#       "uri": "https://westcentralus.api.azureml.ms"
#     },
#     "westus": {
#       "uri": "https://westus.api.azureml.ms"
#     },
#     "westus2": {
#       "uri": "https://westus2.api.azureml.ms"
#     },
#     "westus3": {
#       "uri": "https://westus3.api.azureml.ms"
#     },
#     "australiaeast": {
#       "uri": "https://australiaeast.api.azureml.ms"
#     }
#   },
#   "intellectualPropertyPublisher": null
# }
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 169.254.169.254:80
# DEBUG:urllib3.connectionpool:http://169.254.169.254:80 "GET /metadata/instance/compute?api-version=2017-12-01&format=json HTTP/1.1" 200 535
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westus-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://westus-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None
# DEBUG:azure.identity._internal.decorators:AzureCliCredential.get_token succeeded
# DEBUG:azure.identity._internal.decorators:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: banide@microsoft.com. Object ID (user): 558795a7-7d0c-4b80-b7c6-8f71e52a8bef
# INFO:azure.identity._credentials.default:DefaultAzureCredential acquired a token from AzureCliCredential
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://cert-eastus2.experiments.azureml.net/mferp/managementfrontend/subscriptions/ed2cab61-14cc-4fb3-ac23-d72609214cfd/resourceGroups/fm_demo_meta/providers/Microsoft.MachineLearningServices/registries/msft-meta-preview/models/Llama-2-7b/versions?api-version=2021-10-01-dataplanepreview'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '197d1f5f-20fe-11ee-8e3e-000d3ac5f120'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://cert-eastus2.experiments.azureml.net/mferp/managementfrontend/subscriptions/ed2cab61-14cc-4fb3-ac23-d72609214cfd/resourceGroups/fm_demo_meta/providers/Microsoft.MachineLearningServices/registries/msft-meta-preview/models/Llama-2-7b/versions?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '197d1f5f-20fe-11ee-8e3e-000d3ac5f120'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cert-eastus2.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://cert-eastus2.experiments.azureml.net:443 "GET /mferp/managementfrontend/subscriptions/ed2cab61-14cc-4fb3-ac23-d72609214cfd/resourceGroups/fm_demo_meta/providers/Microsoft.MachineLearningServices/registries/msft-meta-preview/models/Llama-2-7b/versions?api-version=2021-10-01-dataplanepreview HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Wed, 12 Jul 2023 21:50:23 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Date': 'Wed, 12 Jul 2023 21:50:23 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'Accept-Encoding'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
#     'X-Content-Type-Options': 'nosniff, nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.259'
#     'Content-Encoding': 'gzip'
# Response content:
# {
#   "value": [
#     {
#       "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/6",
#       "name": "Llama-2-7b",
#       "type": "models",
#       "properties": {
#         "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper �LLaMA, Open and Efficient Foundation Language Models�, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n\n### Inference samples\n\nInference type|Python sample (Notebook)|CLI with YAML\n|--|--|--|\nReal time|<a href=\"https://aka.ms/azureml-infer-online-sdk-text-generation\" target=\"_blank\">text-generation-online-endpoint.ipynb</a>|<a href=\"https://aka.ms/azureml-infer-online-cli-text-generation\" target=\"_blank\">text-generation-online-endpoint.sh</a>\nBatch |<a href=\"https://aka.ms/azureml-infer-batch-sdk-text-generation\" target=\"_blank\">text-generation-batch-endpoint.ipynb</a>| coming soon\n\n\n### Finetuning samples\n\nTask|Use case|Dataset|Python sample (Notebook)|CLI with YAML\n|--|--|--|--|--|\nText Classification|Emotion Detection|<a href=\"https://huggingface.co/datasets/dair-ai/emotion\" target=\"_blank\">Emotion</a>|<a href=\"https://aka.ms/azureml-ft-sdk-emotion-detection\" target=\"_blank\">emotion-detection.ipynb</a>| coming soon\n\n\n### Model Evaluation\n\nTask| Use case| Dataset| Python sample (Notebook)| CLI with YAML\n|--|--|--|--|--|\nText generation | Text generation | <a href=\"https://huggingface.co/datasets/cnn_dailymail\" target=\"_blank\"> cnn_dailymail </a> | <a href=\"https://aka.ms/azureml-eval-sdk-text-generation/\" target=\"_blank\">evaluate-model-text-generation.ipynb</a> | <a href=\"https://aka.ms/azureml-eval-cli-text-generation/\" target=\"_blank\">evaluate-model-text-generation.yml</a>\n\n\n### Sample inputs and outputs (for real-time inference)\n\n#### Sample input\n```json\n{ \n  \"input_data\": { \n      \"input_string\": [\"the meaning of life is\"], \n      \"parameters\":{   \n              \"top_p\": 0.3,\n              \"temperature\": 0.8, \n              \"max_gen_len\": 100, \n              \"do_sample\": true \n      } \n  } \n}\n```\n\n#### Sample output\n```json\n[\n    {\n        \"0\": \"the meaning of life is to be found in the search for the meaning of life.\\nIn the end, it is all about the journey, not the destination.\\nI am a seeker, a traveler, and I know that the answer to the meaning of life has been looking for me my entire life. I found it by accident, looking for something else, in the last place I thought to look.\\nI am a seeker, a traveler, and I know that the answer to the meaning of\"\n    }\n]\n```\n",
#         "tags": {
#           "Preview": "",
#           "license": "gnu",
#           "task": "text-generation",
#           "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#           "author": "meta",
#           "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#         },
#         "properties": {
#           "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#           "evaluation-min-sku-spec": "16|0|64|128",
#           "evaluation-recommended-sku": "Standard_NC24s_v3",
#           "inference-min-sku-spec": "16|0|64|128",
#           "inference-recommended-sku": "Standard_NC24s_v3",
#           "finetune-min-sku-spec": "4|1|28|176",
#           "finetune-recommended-sku": "Standard_ND40RS_v2",
#           "finetuning-tasks": "text-classification",
#           "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "flavors": {},
#         "modelType": "mlflow_model",
#         "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-0a226673-add5-52cc-bae6-3fb64026b776/mlflow_model_folder",
#         "originAssetId": null,
#         "jobName": null,
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-12T03:53:28.5241206+00:00",
#         "createdBy": "Srujan Saggam",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T21:50:23.4338748+00:00",
#         "lastModifiedBy": "Srujan Saggam",
#         "lastModifiedByType": "User"
#       }
#     },
#     {
#       "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/5",
#       "name": "Llama-2-7b",
#       "type": "models",
#       "properties": {
#         "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper �LLaMA, Open and Efficient Foundation Language Models�, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n\n### Inference samples\n\nInference type|Python sample (Notebook)|CLI with YAML\n|--|--|--|\nReal time|<a href=\"https://aka.ms/azureml-infer-online-sdk-text-generation\" target=\"_blank\">text-generation-online-endpoint.ipynb</a>|<a href=\"https://aka.ms/azureml-infer-online-cli-text-generation\" target=\"_blank\">text-generation-online-endpoint.sh</a>\nBatch |<a href=\"https://aka.ms/azureml-infer-batch-sdk-text-generation\" target=\"_blank\">text-generation-batch-endpoint.ipynb</a>| coming soon\n\n\n### Finetuning samples\n\nTask|Use case|Dataset|Python sample (Notebook)|CLI with YAML\n|--|--|--|--|--|\nText Classification|Emotion Detection|<a href=\"https://huggingface.co/datasets/dair-ai/emotion\" target=\"_blank\">Emotion</a>|<a href=\"https://aka.ms/azureml-ft-sdk-emotion-detection\" target=\"_blank\">emotion-detection.ipynb</a>| coming soon\n\n\n### Model Evaluation\n\nTask| Use case| Dataset| Python sample (Notebook)| CLI with YAML\n|--|--|--|--|--|\nText generation | Text generation | <a href=\"https://huggingface.co/datasets/cnn_dailymail\" target=\"_blank\"> cnn_dailymail </a> | <a href=\"https://aka.ms/azureml-eval-sdk-text-generation/\" target=\"_blank\">evaluate-model-text-generation.ipynb</a> | <a href=\"https://aka.ms/azureml-eval-cli-text-generation/\" target=\"_blank\">evaluate-model-text-generation.yml</a>\n\n\n### Sample inputs and outputs (for real-time inference)\n\n#### Sample input\n```json\n{ \n  \"input_data\": { \n      \"input_string\": [\"the meaning of life is\"], \n      \"parameters\":{   \n              \"top_p\": 0.3,\n              \"temperature\": 0.8, \n              \"max_gen_len\": 100, \n              \"do_sample\": true \n      } \n  } \n}\n```\n\n#### Sample output\n```json\n[\n    {\n        \"0\": \"the meaning of life is to be found in the search for the meaning of life.\\nIn the end, it is all about the journey, not the destination.\\nI am a seeker, a traveler, and I know that the answer to the meaning of life has been looking for me my entire life. I found it by accident, looking for something else, in the last place I thought to look.\\nI am a seeker, a traveler, and I know that the answer to the meaning of\"\n    }\n]\n```\n",
#         "tags": {
#           "Preview": "",
#           "license": "gnu",
#           "task": "text-generation",
#           "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#           "author": "meta",
#           "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#         },
#         "properties": {
#           "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#           "evaluation-min-sku-spec": "16|0|64|128",
#           "evaluation-recommended-sku": "Standard_NC24s_v3",
#           "inference-min-sku-spec": "16|0|64|128",
#           "inference-recommended-sku": "Standard_NC24s_v3",
#           "finetune-min-sku-spec": "4|1|28|176",
#           "finetune-recommended-sku": "Standard_ND40RS_v2",
#           "finetuning-tasks": "text-classification",
#           "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "flavors": {},
#         "modelType": "mlflow_model",
#         "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-bdf24770-125e-5217-8b73-f7fe7f04f505/mlflow_model_folder",
#         "originAssetId": null,
#         "jobName": null,
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-11T17:05:44.9753029+00:00",
#         "createdBy": "Hrishikesh Geed",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T21:50:23.4338807+00:00",
#         "lastModifiedBy": "Hrishikesh Geed",
#         "lastModifiedByType": "User"
#       }
#     },
#     {
#       "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/4",
#       "name": "Llama-2-7b",
#       "type": "models",
#       "properties": {
#         "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper �LLaMA, Open and Efficient Foundation Language Models�, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n\n### Inference samples\n\nInference type|Python sample (Notebook)|CLI with YAML\n|--|--|--|\nReal time|<a href=\"https://aka.ms/azureml-infer-online-sdk-text-generation\" target=\"_blank\">text-generation-online-endpoint.ipynb</a>|<a href=\"https://aka.ms/azureml-infer-online-cli-text-generation\" target=\"_blank\">text-generation-online-endpoint.sh</a>\nBatch |<a href=\"https://aka.ms/azureml-infer-batch-sdk-text-generation\" target=\"_blank\">text-generation-batch-endpoint.ipynb</a>| coming soon\n\n\n### Finetuning samples\n\nTask|Use case|Dataset|Python sample (Notebook)|CLI with YAML\n|--|--|--|--|--|\nText Classification|Emotion Detection|<a href=\"https://huggingface.co/datasets/dair-ai/emotion\" target=\"_blank\">Emotion</a>|<a href=\"https://aka.ms/azureml-ft-sdk-emotion-detection\" target=\"_blank\">emotion-detection.ipynb</a>| coming soon\n\n\n### Model Evaluation\n\nTask| Use case| Dataset| Python sample (Notebook)| CLI with YAML\n|--|--|--|--|--|\nText generation | Text generation | <a href=\"https://huggingface.co/datasets/cnn_dailymail\" target=\"_blank\"> cnn_dailymail </a> | <a href=\"https://aka.ms/azureml-eval-sdk-text-generation/\" target=\"_blank\">evaluate-model-text-generation.ipynb</a> | <a href=\"https://aka.ms/azureml-eval-cli-text-generation/\" target=\"_blank\">evaluate-model-text-generation.yml</a>\n\n\n### Sample inputs and outputs (for real-time inference)\n\n#### Sample input\n```json\n{ \n  \"input_data\": { \n      \"input_string\": [\"the meaning of life is\"], \n      \"parameters\":{   \n              \"top_p\": 0.3,\n              \"temperature\": 0.8, \n              \"max_gen_len\": 100, \n              \"do_sample\": true \n      } \n  } \n}\n```\n\n#### Sample output\n```json\n[\n    {\n        \"0\": \"the meaning of life is to be found in the search for the meaning of life.\\nIn the end, it is all about the journey, not the destination.\\nI am a seeker, a traveler, and I know that the answer to the meaning of life has been looking for me my entire life. I found it by accident, looking for something else, in the last place I thought to look.\\nI am a seeker, a traveler, and I know that the answer to the meaning of\"\n    }\n]\n```\n",
#         "tags": {
#           "Preview": "",
#           "license": "gnu",
#           "task": "text-generation",
#           "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#           "author": "meta",
#           "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#         },
#         "properties": {
#           "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#           "evaluation-min-sku-spec": "16|0|64|128",
#           "evaluation-recommended-sku": "Standard_NC24s_v3",
#           "inference-min-sku-spec": "16|0|64|128",
#           "inference-recommended-sku": "Standard_NC24s_v3",
#           "finetune-min-sku-spec": "4|1|28|176",
#           "finetune-recommended-sku": "Standard_ND40RS_v2",
#           "finetuning-tasks": "text-classification",
#           "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "flavors": {},
#         "modelType": "mlflow_model",
#         "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-b35d10e8-8312-5d48-a333-e94511f2c7f2/mlflow_model_folder",
#         "originAssetId": null,
#         "jobName": null,
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-11T15:05:38.445346+00:00",
#         "createdBy": "Hrishikesh Geed",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T21:50:23.4338816+00:00",
#         "lastModifiedBy": "Hrishikesh Geed",
#         "lastModifiedByType": "User"
#       }
#     },
#     {
#       "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/3",
#       "name": "Llama-2-7b",
#       "type": "models",
#       "properties": {
#         "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper �LLaMA, Open and Efficient Foundation Language Models�, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n\n### Inference samples\n\nInference type|Python sample (Notebook)|CLI with YAML\n|--|--|--|\nReal time|<a href=\"https://aka.ms/azureml-infer-online-sdk-text-generation\" target=\"_blank\">text-generation-online-endpoint.ipynb</a>|<a href=\"https://aka.ms/azureml-infer-online-cli-text-generation\" target=\"_blank\">text-generation-online-endpoint.sh</a>\nBatch |<a href=\"https://aka.ms/azureml-infer-batch-sdk-text-generation\" target=\"_blank\">text-generation-batch-endpoint.ipynb</a>| coming soon\n\n\n### Finetuning samples\n\nTask|Use case|Dataset|Python sample (Notebook)|CLI with YAML\n|--|--|--|--|--|\nText Classification|Emotion Detection|<a href=\"https://huggingface.co/datasets/dair-ai/emotion\" target=\"_blank\">Emotion</a>|<a href=\"https://aka.ms/azureml-ft-sdk-emotion-detection\" target=\"_blank\">emotion-detection.ipynb</a>| coming soon\n\n\n### Model Evaluation\n\nTask| Use case| Dataset| Python sample (Notebook)| CLI with YAML\n|--|--|--|--|--|\nText generation | Text generation | <a href=\"https://huggingface.co/datasets/cnn_dailymail\" target=\"_blank\"> cnn_dailymail </a> | <a href=\"https://aka.ms/azureml-eval-sdk-text-generation/\" target=\"_blank\">evaluate-model-text-generation.ipynb</a> | <a href=\"https://aka.ms/azureml-eval-cli-text-generation/\" target=\"_blank\">evaluate-model-text-generation.yml</a>\n\n\n### Sample inputs and outputs (for real-time inference)\n\n#### Sample input\n```json\n{ \n  \"input_data\": { \n      \"input_string\": [\"the meaning of life is\"], \n      \"parameters\":{   \n              \"top_p\": 0.3,\n              \"temperature\": 0.8, \n              \"max_gen_len\": 100, \n              \"do_sample\": true \n      } \n  } \n}\n```\n\n#### Sample output\n```json\n[\n    {\n        \"0\": \"the meaning of life is to be found in the search for the meaning of life.\\nIn the end, it is all about the journey, not the destination.\\nI am a seeker, a traveler, and I know that the answer to the meaning of life has been looking for me my entire life. I found it by accident, looking for something else, in the last place I thought to look.\\nI am a seeker, a traveler, and I know that the answer to the meaning of\"\n    }\n]\n```\n",
#         "tags": {
#           "Preview": "",
#           "license": "gnu",
#           "task": "text-generation",
#           "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#           "author": "meta",
#           "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#         },
#         "properties": {
#           "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#           "evaluation-min-sku-spec": "16|0|64|128",
#           "evaluation-recommended-sku": "Standard_NC24s_v3",
#           "inference-min-sku-spec": "16|0|64|128",
#           "inference-recommended-sku": "Standard_NC24s_v3",
#           "finetune-min-sku-spec": "4|1|28|176",
#           "finetune-recommended-sku": "Standard_ND40RS_v2",
#           "finetuning-tasks": "text-classification",
#           "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "flavors": {},
#         "modelType": "mlflow_model",
#         "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-b5ecff52-0bc3-56ec-9e28-6bf0068fe9b0/mlflow_model_folder",
#         "originAssetId": null,
#         "jobName": null,
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-11T14:47:12.9257156+00:00",
#         "createdBy": "Hrishikesh Geed",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T21:50:23.4338823+00:00",
#         "lastModifiedBy": "Hrishikesh Geed",
#         "lastModifiedByType": "User"
#       }
#     },
#     {
#       "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/2",
#       "name": "Llama-2-7b",
#       "type": "models",
#       "properties": {
#         "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper “LLaMA, Open and Efficient Foundation Language Models”, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n",
#         "tags": {
#           "Preview": "",
#           "license": "gnu",
#           "task": "text-generation",
#           "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#           "author": "meta",
#           "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#         },
#         "properties": {
#           "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#           "evaluation-min-sku-spec": "16|0|64|128",
#           "evaluation-recommended-sku": "Standard_NC24s_v3",
#           "inference-min-sku-spec": "16|0|64|128",
#           "inference-recommended-sku": "Standard_NC24s_v3",
#           "finetune-min-sku-spec": "4|1|28|176",
#           "finetune-recommended-sku": "Standard_ND40RS_v2",
#           "finetuning-tasks": "text-classification",
#           "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "flavors": {},
#         "modelType": "mlflow_model",
#         "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-eed157d5-e77c-50b2-9f92-b7de4321d044/LocalUpload/9bc864425f033fa9f37aeaaadc267c54/meta-llama-7b",
#         "originAssetId": "azureml://locations/eastus2/workspaces/3518c99e-90fd-4666-81d3-f01743fe8e37/models/meta-llama-7b/versions/6",
#         "jobName": null,
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-10T19:31:33.9301592+00:00",
#         "createdBy": "Srujan Saggam",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T21:50:23.4338875+00:00",
#         "lastModifiedBy": "Srujan Saggam",
#         "lastModifiedByType": "User"
#       }
#     },
#     {
#       "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/1",
#       "name": "Llama-2-7b",
#       "type": "models",
#       "properties": {
#         "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper “LLaMA, Open and Efficient Foundation Language Models”, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n",
#         "tags": {
#           "Preview": "",
#           "license": "gnu",
#           "task": "text-generation",
#           "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#           "author": "meta",
#           "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#         },
#         "properties": {
#           "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#           "evaluation-min-sku-spec": "16|0|64|128",
#           "evaluation-recommended-sku": "Standard_NC24s_v3",
#           "inference-min-sku-spec": "16|0|64|128",
#           "inference-recommended-sku": "Standard_NC24s_v3",
#           "finetune-min-sku-spec": "4|1|28|176",
#           "finetune-recommended-sku": "Standard_ND40RS_v2",
#           "finetuning-tasks": "text-classification",
#           "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "flavors": {},
#         "modelType": "mlflow_model",
#         "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-59929eb2-119d-5fc8-a58b-221241ab5533/mlflow_model_folder",
#         "originAssetId": null,
#         "jobName": null,
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-06T12:51:32.9404014+00:00",
#         "createdBy": "Sasidhar Kasturi",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T21:50:23.4338885+00:00",
#         "lastModifiedBy": "Sasidhar Kasturi",
#         "lastModifiedByType": "User"
#       }
#     }
#   ]
# }
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://cert-eastus2.experiments.azureml.net/mferp/managementfrontend/subscriptions/ed2cab61-14cc-4fb3-ac23-d72609214cfd/resourceGroups/fm_demo_meta/providers/Microsoft.MachineLearningServices/registries/msft-meta-preview/models/Llama-2-7b/versions/6?api-version=2021-10-01-dataplanepreview'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1aa20072-20fe-11ee-8757-000d3ac5f120'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://cert-eastus2.experiments.azureml.net/mferp/managementfrontend/subscriptions/ed2cab61-14cc-4fb3-ac23-d72609214cfd/resourceGroups/fm_demo_meta/providers/Microsoft.MachineLearningServices/registries/msft-meta-preview/models/Llama-2-7b/versions/6?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '1aa20072-20fe-11ee-8757-000d3ac5f120'
#     'User-Agent': 'azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://cert-eastus2.experiments.azureml.net:443 "GET /mferp/managementfrontend/subscriptions/ed2cab61-14cc-4fb3-ac23-d72609214cfd/resourceGroups/fm_demo_meta/providers/Microsoft.MachineLearningServices/registries/msft-meta-preview/models/Llama-2-7b/versions/6?api-version=2021-10-01-dataplanepreview HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Date': 'Wed, 12 Jul 2023 21:50:23 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Date': 'Wed, 12 Jul 2023 21:50:23 GMT'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'Accept-Encoding'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
#     'X-Content-Type-Options': 'nosniff, nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.146'
#     'Content-Encoding': 'gzip'
# Response content:
# {
#   "id": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/6",
#   "name": "Llama-2-7b",
#   "type": "models",
#   "properties": {
#     "description": "## Model details\n**Organization developing the model**\nThe FAIR team of Meta AI.\n\n**Model date**\nLLaMA was trained between December. 2022 and Feb. 2023.\n\n**Model version**\nThis is version 1 of the model.\n\n**Model type**\nLLaMA is an auto-regressive language model, based on the transformer architecture. The model comes in different sizes: 7B, 13B, 33B and 65B parameters.\n\n**Paper or resources for more information**\nMore information can be found in the paper �LLaMA, Open and Efficient Foundation Language Models�, available at https://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/.\n\n**Citations details**\nhttps://research.facebook.com/publications/llama-open-and-efficient-foundation-language-models/\n\n**License**\nNon-commercial bespoke license\n\n**Model training reference**\nLlama (by Meta AI)\n\n### Inference samples\n\nInference type|Python sample (Notebook)|CLI with YAML\n|--|--|--|\nReal time|<a href=\"https://aka.ms/azureml-infer-online-sdk-text-generation\" target=\"_blank\">text-generation-online-endpoint.ipynb</a>|<a href=\"https://aka.ms/azureml-infer-online-cli-text-generation\" target=\"_blank\">text-generation-online-endpoint.sh</a>\nBatch |<a href=\"https://aka.ms/azureml-infer-batch-sdk-text-generation\" target=\"_blank\">text-generation-batch-endpoint.ipynb</a>| coming soon\n\n\n### Finetuning samples\n\nTask|Use case|Dataset|Python sample (Notebook)|CLI with YAML\n|--|--|--|--|--|\nText Classification|Emotion Detection|<a href=\"https://huggingface.co/datasets/dair-ai/emotion\" target=\"_blank\">Emotion</a>|<a href=\"https://aka.ms/azureml-ft-sdk-emotion-detection\" target=\"_blank\">emotion-detection.ipynb</a>| coming soon\n\n\n### Model Evaluation\n\nTask| Use case| Dataset| Python sample (Notebook)| CLI with YAML\n|--|--|--|--|--|\nText generation | Text generation | <a href=\"https://huggingface.co/datasets/cnn_dailymail\" target=\"_blank\"> cnn_dailymail </a> | <a href=\"https://aka.ms/azureml-eval-sdk-text-generation/\" target=\"_blank\">evaluate-model-text-generation.ipynb</a> | <a href=\"https://aka.ms/azureml-eval-cli-text-generation/\" target=\"_blank\">evaluate-model-text-generation.yml</a>\n\n\n### Sample inputs and outputs (for real-time inference)\n\n#### Sample input\n```json\n{ \n  \"input_data\": { \n      \"input_string\": [\"the meaning of life is\"], \n      \"parameters\":{   \n              \"top_p\": 0.3,\n              \"temperature\": 0.8, \n              \"max_gen_len\": 100, \n              \"do_sample\": true \n      } \n  } \n}\n```\n\n#### Sample output\n```json\n[\n    {\n        \"0\": \"the meaning of life is to be found in the search for the meaning of life.\\nIn the end, it is all about the journey, not the destination.\\nI am a seeker, a traveler, and I know that the answer to the meaning of life has been looking for me my entire life. I found it by accident, looking for something else, in the last place I thought to look.\\nI am a seeker, a traveler, and I know that the answer to the meaning of\"\n    }\n]\n```\n",
#     "tags": {
#       "Preview": "",
#       "license": "gnu",
#       "task": "text-generation",
#       "computes_allow_list": "['Standard_ND40rs_v2', 'Standard_ND96asr_v4']",
#       "author": "meta",
#       "model_specific_defaults": "{'apply_deepspeed': 'true', 'apply_lora': 'true', 'precision': 16}"
#     },
#     "properties": {
#       "datasets": "CCNet [67%], C4 [15%], GitHub [4.5%], Wikipedia [4.5%], Books [4.5%], ArXiv [2.5%], Stack Exchange[2%]",
#       "evaluation-min-sku-spec": "16|0|64|128",
#       "evaluation-recommended-sku": "Standard_NC24s_v3",
#       "inference-min-sku-spec": "16|0|64|128",
#       "inference-recommended-sku": "Standard_NC24s_v3",
#       "finetune-min-sku-spec": "4|1|28|176",
#       "finetune-recommended-sku": "Standard_ND40RS_v2",
#       "finetuning-tasks": "text-classification",
#       "languages": "bg,ca,cs,da,de,en,es,fr,hr,hu,it,nl,pl,pt,ro,ru,sl,sr,sv,uk"
#     },
#     "isArchived": false,
#     "isAnonymous": false,
#     "flavors": {},
#     "modelType": "mlflow_model",
#     "modelUri": "https://2e521359d7e.blob.core.windows.net/msft-meta-0a226673-add5-52cc-bae6-3fb64026b776/mlflow_model_folder",
#     "originAssetId": null,
#     "jobName": null,
#     "intellectualProperty": null
#   },
#   "systemData": {
#     "createdAt": "2023-07-12T03:53:28.5241206+00:00",
#     "createdBy": "Srujan Saggam",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-07-12T03:53:28.063991+00:00",
#     "lastModifiedBy": "Srujan Saggam",
#     "lastModifiedByType": "User"
#   }
# }
# Using model name: Llama-2-7b, version: 6, id: azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/6 for inferencing

# %% [markdown]
# #### 3.2 Create Llama batch endpoint
# This step may take a few minutes.

# %%
from azure.ai.ml.entities import BatchEndpoint
import logging
logging.basicConfig(level=logging.DEBUG)
endpoint_name = "bani-batch-4"
# Check if the endpoint already exists in the workspace
try:
    endpoint = ml_client.batch_endpoints.get(endpoint_name)
    print("---Endpoint already exists---")
except:
    # Create an batch endpoint if it doesn't exist

    # Define the endpoint
    endpoint = BatchEndpoint(
        name=endpoint_name, description="Test endpoint for model"
    )

    # Trigger the endpoint creation
    try:
        ml_client.begin_create_or_update(endpoint).wait()
        print("\n---Endpoint created successfully---\n")
    except Exception as err:
        raise RuntimeError(
            f"Endpoint creation failed. Detailed Response:\n{err}"
        ) from err
# Out:
# DEBUG:azure.identity._internal.decorators:AzureCliCredential.get_token succeeded
# DEBUG:azure.identity._internal.decorators:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: banide@microsoft.com. Object ID (user): 558795a7-7d0c-4b80-b7c6-8f71e52a8bef
# INFO:azure.identity._credentials.default:DefaultAzureCredential acquired a token from AzureCliCredential
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4?api-version=2022-05-01'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f653a3ae-20fd-11ee-836c-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f653a3ae-20fd-11ee-836c-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): management.azure.com:443
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4?api-version=2022-05-01 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': '27d914b3-0aa4-4eba-bd33-64d8bed5f054'
#     'x-ms-ratelimit-remaining-subscription-reads': '11999'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:49:24 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': '27d914b3-0aa4-4eba-bd33-64d8bed5f054'
#     'x-ms-ratelimit-remaining-subscription-reads': '11999'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.073'
#     'x-ms-correlation-request-id': '27d914b3-0aa4-4eba-bd33-64d8bed5f054'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T214924Z:27d914b3-0aa4-4eba-bd33-64d8bed5f054'
#     'Date': 'Wed, 12 Jul 2023 21:49:24 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4",
#   "name": "bani-batch-4",
#   "type": "Microsoft.MachineLearningServices/workspaces/batchEndpoints",
#   "properties": {
#     "description": "Test endpoint for model",
#     "properties": {
#       "BatchEndpointCreationApiVersion": "2022-05-01",
#       "azureml.onlineendpointid": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4"
#     },
#     "scoringUri": "https://bani-batch-4.eastus2.inference.ml.azure.com/jobs",
#     "swaggerUri": null,
#     "authMode": "AADToken",
#     "defaults": {
#       "deploymentName": "bani-llama-dep"
#     },
#     "provisioningState": "Succeeded"
#   },
#   "systemData": {
#     "createdAt": "2023-07-12T17:24:43.9863541+00:00",
#     "createdBy": "Banibrata De",
#     "lastModifiedAt": "2023-07-12T17:33:59.6061961+00:00"
#   },
#   "tags": {},
#   "location": "eastus2"
# }
# ---Endpoint already exists---

# %% [markdown]
# ##### 3.3 Create environment for Llama endpoint

# %%
from IPython.core.display import display, HTML
from azure.ai.ml.entities import Environment, BuildContext

try:
    env = ml_client.environments.get(environment_name, label="latest")
    print("---Environment already exists---")
except:
    print("---Creating environment---")
    env = Environment(
        name=environment_name, build=BuildContext(path="./llama-files/docker_env")
    )
    ml_client.environments.create_or_update(env)
    env = ml_client.environments.get(environment_name, label="latest")
    print("---Please use link below to check build status---")


display(
    HTML(
        f"""
             <a href="https://ml.azure.com/environments/{environment_name}/version/{env.version}?wsid=/subscriptions/{subscription_id}/resourceGroups/{resource_group}/providers/Microsoft.MachineLearningServices/workspaces/{workspace}">
                Click here to check env build status in AML studio
             </a>
             """
    )
)
# Out:
# C:\Users\banide\AppData\Local\Temp\ipykernel_11416\3332616466.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# DEBUG:azure.identity._internal.decorators:AzureCliCredential.get_token succeeded
# DEBUG:azure.identity._internal.decorators:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: banide@microsoft.com. Object ID (user): 558795a7-7d0c-4b80-b7c6-8f71e52a8bef
# INFO:azure.identity._credentials.default:DefaultAzureCredential acquired a token from AzureCliCredential
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions?api-version=2023-04-01-preview&$orderBy=createdtime%20desc&$top=1'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fb2acadc-20fd-11ee-8dca-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions?api-version=REDACTED&$orderBy=REDACTED&$top=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fb2acadc-20fd-11ee-8dca-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): management.azure.com:443
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions?api-version=2023-04-01-preview&$orderBy=createdtime%20desc&$top=1 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': 'fb107b3b-c44d-47ed-a495-7170206cbb35'
#     'x-ms-ratelimit-remaining-subscription-reads': '11998'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:49:32 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': 'fb107b3b-c44d-47ed-a495-7170206cbb35'
#     'x-ms-ratelimit-remaining-subscription-reads': '11998'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.130'
#     'x-ms-correlation-request-id': 'fb107b3b-c44d-47ed-a495-7170206cbb35'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T214932Z:fb107b3b-c44d-47ed-a495-7170206cbb35'
#     'Date': 'Wed, 12 Jul 2023 21:49:32 GMT'
# Response content:
# {
#   "value": [
#     {
#       "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions/1",
#       "name": "1",
#       "type": "Microsoft.MachineLearningServices/workspaces/environments/versions",
#       "properties": {
#         "description": null,
#         "tags": {},
#         "properties": {},
#         "isArchived": false,
#         "isAnonymous": false,
#         "autoDeleteSetting": null,
#         "environmentType": "UserCreated",
#         "condaFile": "",
#         "build": {
#           "contextUri": "https://banillmws0691280426.blob.core.windows.net/azureml-blobstore-4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d/LocalUpload/9937850f8b751d30cfebb415e399938d/docker_env/",
#           "dockerfilePath": "Dockerfile"
#         },
#         "osType": "Linux",
#         "autoRebuild": "Disabled",
#         "provisioningState": "Succeeded",
#         "stage": "Development",
#         "intellectualProperty": null
#       },
#       "systemData": {
#         "createdAt": "2023-07-12T17:50:37.0926561+00:00",
#         "createdBy": "Banibrata De",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T17:50:37.0926561+00:00",
#         "lastModifiedBy": "Banibrata De",
#         "lastModifiedByType": "User"
#       }
#     }
#   ]
# }
# ---Environment already exists---
#              <a href="https://ml.azure.com/environments/for-llama-env/version/1?wsid=/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws">
#                 Click here to check env build status in AML studio
#              </a>

# %%
from azure.ai.ml import Input
from azure.ai.ml.entities import (
    BatchEndpoint,
    ModelBatchDeployment,
    ModelBatchDeploymentSettings,
    Model,
    AmlCompute,
    Data,
    BatchRetrySettings,
    CodeConfiguration,
    Environment,
)
from azure.ai.ml.constants import AssetTypes, BatchDeploymentOutputAction

compute_name = "gpu-cluster"
if not any(filter(lambda m: m.name == compute_name, ml_client.compute.list())):
    compute_cluster = AmlCompute(
        name=compute_name,
        description="GPU cluster compute",
        size="Standard_Nc6",
        min_instances=0,
        max_instances=2,
    )
    ml_client.compute.begin_create_or_update(compute_cluster).result()
# Out:
# DEBUG:azure.identity._internal.decorators:AzureCliCredential.get_token succeeded
# DEBUG:azure.identity._internal.decorators:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: banide@microsoft.com. Object ID (user): 558795a7-7d0c-4b80-b7c6-8f71e52a8bef
# INFO:azure.identity._credentials.default:DefaultAzureCredential acquired a token from AzureCliCredential
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes?api-version=2022-10-01-preview'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '00ddc9f3-20fe-11ee-9c23-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '00ddc9f3-20fe-11ee-9c23-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): management.azure.com:443
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes?api-version=2022-10-01-preview HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': '33946dc6-d3da-46cb-a4a2-e7cd51daef43'
#     'x-ms-ratelimit-remaining-subscription-reads': '11999'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:49:41 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': '33946dc6-d3da-46cb-a4a2-e7cd51daef43'
#     'x-ms-ratelimit-remaining-subscription-reads': '11999'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.151'
#     'x-ms-correlation-request-id': '33946dc6-d3da-46cb-a4a2-e7cd51daef43'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T214942Z:33946dc6-d3da-46cb-a4a2-e7cd51daef43'
#     'Date': 'Wed, 12 Jul 2023 21:49:41 GMT'
# Response content:
# {
#   "value": [
#     {
#       "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes/banide1",
#       "name": "banide1",
#       "type": "Microsoft.MachineLearningServices/workspaces/computes",
#       "location": "eastus2",
#       "tags": {},
#       "properties": {
#         "createdOn": "2023-07-11T22:43:15.2357806+00:00",
#         "modifiedOn": "2023-07-12T00:00:15.1969157+00:00",
#         "disableLocalAuth": true,
#         "description": null,
#         "resourceId": null,
#         "computeType": "ComputeInstance",
#         "computeLocation": "eastus2",
#         "provisioningState": "Succeeded",
#         "provisioningErrors": null,
#         "provisioningWarnings": {},
#         "isAttachedCompute": false,
#         "properties": {
#           "vmSize": "STANDARD_DS11_V2",
#           "imageVersion": null,
#           "subnet": null,
#           "sshSettings": {
#             "sshPublicAccess": "Disabled",
#             "adminUserName": "azureuser",
#             "sshPort": 4000,
#             "adminPublicKey": null
#           },
#           "autologgerSettings": null,
#           "errors": [],
#           "connectivityEndpoints": {
#             "publicIpAddress": "20.85.105.188",
#             "privateIpAddress": "10.0.0.4"
#           },
#           "applications": [
#             {
#               "displayName": "Jupyter",
#               "endpointUri": "https://banide1.eastus2.instances.azureml.ms/tree/"
#             },
#             {
#               "displayName": "Jupyter Lab",
#               "endpointUri": "https://banide1.eastus2.instances.azureml.ms/lab"
#             }
#           ],
#           "state": "Stopped",
#           "lastOperation": {
#             "operationName": "Stop",
#             "operationTime": "2023-07-11T23:58:42.118+00:00",
#             "operationStatus": "Succeeded",
#             "operationTrigger": "User"
#           },
#           "createdBy": {
#             "userOrgId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#             "userId": "558795a7-7d0c-4b80-b7c6-8f71e52a8bef"
#           },
#           "applicationSharingPolicy": "Shared",
#           "computeInstanceAuthorizationType": null,
#           "personalComputeInstanceSettings": null,
#           "setupScripts": null,
#           "idleTimeBeforeShutdown": "PT60M",
#           "schedules": {
#             "computeStartStop": []
#           },
#           "enableBatchPrivateLink": false,
#           "dataMounts": null,
#           "dataDisks": null,
#           "containers": null,
#           "updateStatus": "Completed",
#           "versions": {
#             "runtime": "3.0.02370.0001"
#           },
#           "customServices": [],
#           "osImageMetadata": {
#             "currentImageVersion": "23.04.07",
#             "latestImageVersion": "23.04.07",
#             "isLatestOsImageVersion": true
#           }
#         }
#       }
#     },
#     {
#       "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes/gpu-cluster",
#       "name": "gpu-cluster",
#       "type": "Microsoft.MachineLearningServices/workspaces/computes",
#       "location": "eastus2",
#       "tags": {},
#       "properties": {
#         "createdOn": "2023-07-11T23:44:07.13348+00:00",
#         "modifiedOn": "2023-07-12T05:49:22.5130116+00:00",
#         "disableLocalAuth": false,
#         "description": "GPU cluster compute",
#         "resourceId": null,
#         "computeType": "AmlCompute",
#         "computeLocation": "eastus2",
#         "provisioningState": "Succeeded",
#         "provisioningErrors": null,
#         "provisioningWarnings": {},
#         "isAttachedCompute": false,
#         "properties": {
#           "vmSize": "STANDARD_NC6",
#           "vmPriority": "Dedicated",
#           "scaleSettings": {
#             "maxNodeCount": 2,
#             "minNodeCount": 0,
#             "nodeIdleTimeBeforeScaleDown": "PT25M"
#           },
#           "subnet": null,
#           "currentNodeCount": 0,
#           "targetNodeCount": 0,
#           "nodeStateCounts": {
#             "preparingNodeCount": 0,
#             "runningNodeCount": 0,
#             "idleNodeCount": 0,
#             "unusableNodeCount": 0,
#             "leavingNodeCount": 0,
#             "preemptedNodeCount": 0
#           },
#           "allocationState": "Steady",
#           "allocationStateTransitionTime": "2023-07-12T20:38:56.347+00:00",
#           "errors": [
#             {
#               "error": {
#                 "code": "ClusterHasWarnings",
#                 "message": "The specified VMSize STANDARD_NC6 is being deprecated by targetDate: 07/31/2023 More details can be found at : https://learn.microsoft.com/en-us/azure/virtual-machines/n-series-migration. Please use any of the recommended VMSizes mentioned in the link to recreate the compute."
#               }
#             }
#           ],
#           "remoteLoginPortPublicAccess": "Enabled",
#           "osType": "Linux",
#           "virtualMachineImage": null,
#           "isolatedNetwork": false,
#           "enableNodePublicIp": true,
#           "enableBatchPrivateLink": false,
#           "propertyBag": {}
#         }
#       }
#     }
#   ]
# }

# %% [markdown]
# ##### 3.4 Deploy Llama model
# This step may take a few minutes.

# %%
import os
deployment = ModelBatchDeployment(
    name=deployment_name,
    endpoint_name=endpoint.name,
    model=llama_model,
    environment=env,
    code_configuration=CodeConfiguration(
        code="llama-files/score",
        scoring_script="score_batch.py",
    ),
    compute=compute_name,
    environment_variables={
        "MLFLOW_MODEL_FOLDER": os.path.basename(llama_model.path),
        "CONTENT_SAFETY_ENDPOINT": "aacs_endpoint",
        "CONTENT_SAFETY_KEY": "aacs_access_key",
    },
    settings=ModelBatchDeploymentSettings(
        instance_count=1,
        max_concurrency_per_instance=1,
        mini_batch_size=1,
        output_action=BatchDeploymentOutputAction.APPEND_ROW,
        output_file_name="predictions.csv",
        retry_settings=BatchRetrySettings(max_retries=3, timeout=3000),
        logging_level="info",
    ),
)
# Trigger the deployment creation
try:
    ml_client.begin_create_or_update(deployment).wait()
    print("\n---Deployment created successfully---\n")
except Exception as err:
    raise RuntimeError(
        f"Deployment creation failed. Detailed Response:\n{err}"
    ) from err
# Out:
# Class ModelBatchDeploymentSettings: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class ModelBatchDeployment: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4?api-version=2022-05-01'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '2111aa0e-20fe-11ee-bf6b-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '2111aa0e-20fe-11ee-bf6b-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4?api-version=2022-05-01 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': 'a9f084bd-bce6-4d18-9c08-188ac3e88923'
#     'x-ms-ratelimit-remaining-subscription-reads': '11998'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:50:34 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': 'a9f084bd-bce6-4d18-9c08-188ac3e88923'
#     'x-ms-ratelimit-remaining-subscription-reads': '11998'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-01'
#     'x-request-time': '0.058'
#     'x-ms-correlation-request-id': 'a9f084bd-bce6-4d18-9c08-188ac3e88923'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215034Z:a9f084bd-bce6-4d18-9c08-188ac3e88923'
#     'Date': 'Wed, 12 Jul 2023 21:50:34 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4",
#   "name": "bani-batch-4",
#   "type": "Microsoft.MachineLearningServices/workspaces/batchEndpoints",
#   "properties": {
#     "description": "Test endpoint for model",
#     "properties": {
#       "BatchEndpointCreationApiVersion": "2022-05-01",
#       "azureml.onlineendpointid": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4"
#     },
#     "scoringUri": "https://bani-batch-4.eastus2.inference.ml.azure.com/jobs",
#     "swaggerUri": null,
#     "authMode": "AADToken",
#     "defaults": {
#       "deploymentName": "bani-llama-dep"
#     },
#     "provisioningState": "Succeeded"
#   },
#   "systemData": {
#     "createdAt": "2023-07-12T17:24:43.9863541+00:00",
#     "createdBy": "Banibrata De",
#     "lastModifiedAt": "2023-07-12T17:33:59.6061961+00:00"
#   },
#   "tags": {},
#   "location": "eastus2"
# }
# DEBUG:azure.identity._internal.decorators:AzureCliCredential.get_token succeeded
# DEBUG:azure.identity._internal.decorators:[Authenticated account] Client ID: 04b07795-8ddb-461a-bbee-02f9e1bf7b46. Tenant ID: 72f988bf-86f1-41af-91ab-2d7cd011db47. User Principal Name: banide@microsoft.com. Object ID (user): 558795a7-7d0c-4b80-b7c6-8f71e52a8bef
# INFO:azure.identity._credentials.default:DefaultAzureCredential acquired a token from AzureCliCredential
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/41aaaadd-830d-43f4-8243-7847d3a7081c/versions?api-version=2023-04-01&hash=505a49f551590933a88314142aa20852a06917012f0f8e3d6e7956e3fcb1b092&hashVersion=202208'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '2155d7d8-20fe-11ee-b8fb-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/41aaaadd-830d-43f4-8243-7847d3a7081c/versions?api-version=REDACTED&hash=REDACTED&hashVersion=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '2155d7d8-20fe-11ee-b8fb-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): management.azure.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): dc.services.visualstudio.com:443
# DEBUG:urllib3.connectionpool:https://dc.services.visualstudio.com:443 "POST /v2.1/track HTTP/1.1" 307 1068
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westus2-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://westus2-0.in.applicationinsights.azure.com:443 "POST /v2.1/track HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/41aaaadd-830d-43f4-8243-7847d3a7081c/versions?api-version=2023-04-01&hash=505a49f551590933a88314142aa20852a06917012f0f8e3d6e7956e3fcb1b092&hashVersion=202208 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': 'b912912d-9f7b-4f36-8c53-94d345ee609d'
#     'x-ms-ratelimit-remaining-subscription-reads': '11999'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:50:37 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': 'b912912d-9f7b-4f36-8c53-94d345ee609d'
#     'x-ms-ratelimit-remaining-subscription-reads': '11999'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.101'
#     'x-ms-correlation-request-id': 'b912912d-9f7b-4f36-8c53-94d345ee609d'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215037Z:b912912d-9f7b-4f36-8c53-94d345ee609d'
#     'Date': 'Wed, 12 Jul 2023 21:50:37 GMT'
# Response content:
# {
#   "value": [
#     {
#       "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1",
#       "name": "1",
#       "type": "Microsoft.MachineLearningServices/workspaces/codes/versions",
#       "properties": {
#         "description": null,
#         "tags": {},
#         "properties": {
#           "hash_sha256": "505a49f551590933a88314142aa20852a06917012f0f8e3d6e7956e3fcb1b092",
#           "hash_version": "202208"
#         },
#         "isArchived": false,
#         "isAnonymous": false,
#         "codeUri": "https://banillmws0691280426.blob.core.windows.net:443/4eaba3e0-b-b1f73eda-4de4-55e9-adb3-14d91c4ca320/score",
#         "provisioningState": "Succeeded"
#       },
#       "systemData": {
#         "createdAt": "2023-07-12T17:25:17.6194283+00:00",
#         "createdBy": "Banibrata De",
#         "createdByType": "User",
#         "lastModifiedAt": "2023-07-12T17:25:17.6194283+00:00",
#         "lastModifiedBy": "Banibrata De",
#         "lastModifiedByType": "User"
#       }
#     }
#   ]
# }
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1?api-version=2023-04-01'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '22af682f-20fe-11ee-8a3c-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '22af682f-20fe-11ee-8a3c-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1?api-version=2023-04-01 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': 'c554a2da-2173-48c1-8bc8-43fce040acf3'
#     'x-ms-ratelimit-remaining-subscription-reads': '11998'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:50:37 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': 'c554a2da-2173-48c1-8bc8-43fce040acf3'
#     'x-ms-ratelimit-remaining-subscription-reads': '11998'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.041'
#     'x-ms-correlation-request-id': 'c554a2da-2173-48c1-8bc8-43fce040acf3'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215037Z:c554a2da-2173-48c1-8bc8-43fce040acf3'
#     'Date': 'Wed, 12 Jul 2023 21:50:37 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1",
#   "name": "1",
#   "type": "Microsoft.MachineLearningServices/workspaces/codes/versions",
#   "properties": {
#     "description": null,
#     "tags": {},
#     "properties": {
#       "hash_sha256": "505a49f551590933a88314142aa20852a06917012f0f8e3d6e7956e3fcb1b092",
#       "hash_version": "202208"
#     },
#     "isArchived": false,
#     "isAnonymous": false,
#     "codeUri": "https://banillmws0691280426.blob.core.windows.net:443/4eaba3e0-b-b1f73eda-4de4-55e9-adb3-14d91c4ca320/score",
#     "provisioningState": "Succeeded"
#   },
#   "systemData": {
#     "createdAt": "2023-07-12T17:25:17.6194283+00:00",
#     "createdBy": "Banibrata De",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-07-12T17:25:17.6194283+00:00",
#     "lastModifiedBy": "Banibrata De",
#     "lastModifiedByType": "User"
#   }
# }
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws?api-version=2023-04-01-preview'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '22d16537-20fe-11ee-8f70-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '22d16537-20fe-11ee-8f70-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws?api-version=2023-04-01-preview HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': '8aaf0680-3efd-4ffd-892f-57cae15f75b2'
#     'x-ms-ratelimit-remaining-subscription-reads': '11997'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:50:36 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': '8aaf0680-3efd-4ffd-892f-57cae15f75b2'
#     'x-ms-ratelimit-remaining-subscription-reads': '11997'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-02'
#     'x-request-time': '0.019'
#     'x-ms-correlation-request-id': '8aaf0680-3efd-4ffd-892f-57cae15f75b2'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215037Z:8aaf0680-3efd-4ffd-892f-57cae15f75b2'
#     'Date': 'Wed, 12 Jul 2023 21:50:36 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws",
#   "name": "bani-llm-ws",
#   "type": "Microsoft.MachineLearningServices/workspaces",
#   "location": "eastus2",
#   "tags": {},
#   "etag": null,
#   "properties": {
#     "friendlyName": "bani-llm-ws",
#     "description": "",
#     "storageAccount": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.Storage/storageAccounts/banillmws0691280426",
#     "keyVault": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.Keyvault/vaults/banillmws7906836678",
#     "applicationInsights": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.insights/components/banillmws8590234215",
#     "hbiWorkspace": false,
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "imageBuildCompute": null,
#     "provisioningState": "Succeeded",
#     "managedNetwork": {
#       "changeableIsolationModes": [
#         "AllowInternetOutbound",
#         "AllowOnlyApprovedOutbound"
#       ],
#       "isolationMode": "Disabled"
#     },
#     "v1LegacyMode": false,
#     "softDeleteEnabled": false,
#     "containerRegistry": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.ContainerRegistry/registries/4eaba3e0b3d04fbaafd9d74dd2d1ba9d",
#     "creationTime": "2023-07-07T17:33:02.1867460Z",
#     "notebookInfo": {
#       "resourceId": "fb5bae4ac0644263a52041d257eed15a",
#       "fqdn": "ml-bani-llm-ws-eastus2-4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d.eastus2.notebooks.azure.net",
#       "isPrivateLinkEnabled": false,
#       "notebookPreparationError": null
#     },
#     "storageHnsEnabled": false,
#     "workspaceId": "4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d",
#     "linkedModelInventoryArmId": null,
#     "privateLinkCount": 0,
#     "publicNetworkAccess": "Enabled",
#     "discoveryUrl": "https://eastus2.api.azureml.ms/discovery",
#     "mlFlowTrackingUri": "azureml://eastus2.api.azureml.ms/mlflow/v1.0/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws",
#     "sdkTelemetryAppInsightsKey": "e1f7b545-6243-4abf-ba76-c5691d2edb62",
#     "sasGetterUri": "",
#     "enableDataIsolation": false,
#     "azureOpenAI": {
#       "provisioningState": "NotStarted",
#       "resourceId": null,
#       "endpoint": null,
#       "proxyResourceId": null,
#       "failureReason": null
#     }
#   },
#   "identity": {
#     "type": "SystemAssigned",
#     "principalId": "1c3684b7-9ee7-4452-9f6f-4930b225d334",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#   },
#   "kind": "Default",
#   "sku": {
#     "name": "Basic",
#     "tier": "Basic"
#   },
#   "systemData": {
#     "createdAt": "2023-07-07T17:33:02.186746Z",
#     "createdBy": "banide@microsoft.com",
#     "createdByType": "User",
#     "lastModifiedAt": "2023-07-07T17:33:02.186746Z",
#     "lastModifiedBy": "banide@microsoft.com",
#     "lastModifiedByType": "User"
#   }
# }
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=2022-05-01'
# Request method: 'PUT'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1169'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# {"tags": {}, "location": "eastus2", "properties": {"codeConfiguration": {"codeId": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1", "scoringScript": "score_batch.py"}, "environmentId": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions/1", "environmentVariables": {"MLFLOW_MODEL_FOLDER": "mlflow_model_folder", "CONTENT_SAFETY_ENDPOINT": "aacs_endpoint", "CONTENT_SAFETY_KEY": "aacs_access_key"}, "compute": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes/gpu-cluster", "loggingLevel": "info", "maxConcurrencyPerInstance": 1, "miniBatchSize": 1, "model": {"referenceType": "Id", "assetId": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/6"}, "outputAction": "AppendRow", "outputFileName": "predictions.csv", "retrySettings": {"maxRetries": 3, "timeout": "PT50M"}}}
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1169'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "PUT /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=2022-05-01 HTTP/1.1" 201 2008
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 201
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '2008'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Location': 'REDACTED'
#     'x-ms-ratelimit-remaining-subscription-resource-requests': '24'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Azure-AsyncOperation': 'REDACTED'
#     'x-ms-async-operation-timeout': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-request-id': '784b5ac7-5554-450f-a15f-5e20aa92e4f1'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:50:38 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '201'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Content-Length': '2008'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Expires': '-1'
#     'Location': 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=2022-05-01'
#     'x-ms-ratelimit-remaining-subscription-resource-requests': '24'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Azure-AsyncOperation': 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=2022-05-01'
#     'x-ms-async-operation-timeout': 'PT30M'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-01'
#     'x-request-time': '0.445'
#     'x-ms-request-id': '784b5ac7-5554-450f-a15f-5e20aa92e4f1'
#     'x-ms-correlation-request-id': '784b5ac7-5554-450f-a15f-5e20aa92e4f1'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215038Z:784b5ac7-5554-450f-a15f-5e20aa92e4f1'
#     'Date': 'Wed, 12 Jul 2023 21:50:38 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep",
#   "name": "bani-llama-dep",
#   "type": "Microsoft.MachineLearningServices/workspaces/batchEndpoints/deployments",
#   "properties": {
#     "description": null,
#     "properties": {},
#     "codeConfiguration": {
#       "codeId": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1",
#       "scoringScript": "score_batch.py"
#     },
#     "environmentId": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions/1",
#     "environmentVariables": {
#       "MLFLOW_MODEL_FOLDER": "mlflow_model_folder",
#       "CONTENT_SAFETY_ENDPOINT": "aacs_endpoint",
#       "CONTENT_SAFETY_KEY": "aacs_access_key"
#     },
#     "compute": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes/gpu-cluster",
#     "errorThreshold": -1,
#     "retrySettings": {
#       "maxRetries": 3,
#       "timeout": "PT50M"
#     },
#     "miniBatchSize": 1,
#     "loggingLevel": "Info",
#     "model": {
#       "referenceType": "Id",
#       "assetId": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/6"
#     },
#     "maxConcurrencyPerInstance": 1,
#     "outputAction": "AppendRow",
#     "outputFileName": "predictions.csv",
#     "resources": {
#       "instanceCount": 1,
#       "instanceType": null,
#       "properties": null
#     },
#     "provisioningState": "Updating"
#   },
#   "systemData": {
#     "createdAt": "2023-07-12T17:25:19.3014602+00:00",
#     "createdBy": "Banibrata De",
#     "lastModifiedAt": "2023-07-12T21:50:38.3137505+00:00"
#   },
#   "tags": {},
#   "location": "eastus2"
# }
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=2022-05-01'
# Request method: 'GET'
# Request headers:
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=2022-05-01 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': '3362ca52-08c2-408c-8f59-6bfe5dada188'
#     'x-ms-ratelimit-remaining-subscription-reads': '11997'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:50:38 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': '3362ca52-08c2-408c-8f59-6bfe5dada188'
#     'x-ms-ratelimit-remaining-subscription-reads': '11997'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-01'
#     'x-request-time': '0.032'
#     'x-ms-correlation-request-id': '3362ca52-08c2-408c-8f59-6bfe5dada188'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215038Z:3362ca52-08c2-408c-8f59-6bfe5dada188'
#     'Date': 'Wed, 12 Jul 2023 21:50:38 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7",
#   "name": "bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7",
#   "status": "Updating"
# }
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westus2-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://westus2-0.in.applicationinsights.azure.com:443 "POST /v2.1/track HTTP/1.1" 200 None
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=2022-05-01'
# Request method: 'GET'
# Request headers:
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7?api-version=2022-05-01 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': 'de83c75e-3d17-4811-a7d8-74dc8b0b5b6d'
#     'x-ms-ratelimit-remaining-subscription-reads': '11996'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:51:08 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': 'de83c75e-3d17-4811-a7d8-74dc8b0b5b6d'
#     'x-ms-ratelimit-remaining-subscription-reads': '11996'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-01'
#     'x-request-time': '0.055'
#     'x-ms-correlation-request-id': 'de83c75e-3d17-4811-a7d8-74dc8b0b5b6d'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215109Z:de83c75e-3d17-4811-a7d8-74dc8b0b5b6d'
#     'Date': 'Wed, 12 Jul 2023 21:51:08 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/providers/Microsoft.MachineLearningServices/locations/eastus2/mfeOperationsStatus/bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7",
#   "name": "bdbes:4eaba3e0-b3d0-4fba-afd9-d74dd2d1ba9d:bf82ff94-64a9-4653-8281-e837d8e8aed7",
#   "status": "Succeeded"
# }
# DEBUG:azure.core.pipeline.policies._universal:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=2022-05-01'
# Request method: 'GET'
# Request headers:
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyIsImtpZCI6Ii1LSTNROW5OUjdiUm9meG1lWm9YcWJIWkdldyJ9.....n1y5p8PwzX1V7MlPAAUUe1K-0RkwKCC-oqVT3euiRIw7aTf8aQx539o6tjm03PzImCCTwnhu4i4EoiSdf25OBg3ob7Vh_FPuWG8HM4LxwHya_XM31423jSEG9_KYDrkV8wt2ALBauHbDDSZ8OTQJa0cufc0R1DyCVuRkzA6mrdt95Y0j3iqURqKDI_gCV8C8smVCi0SIV0BwbvrOPkdawNwXB8KiDnEahrOKccB_5Q7g6wTyogGFqi0gc7t4EMdPJilCWCShKrnN4Z4arpFlBOE5AmVZDBfzgmZPvCCAaUpT16UQS1cmRLs2XBkcLCwumiCnR3P6A5bLBnTET2wZrg'
# Request body:
# This request has no body
# INFO:azure.core.pipeline.policies.http_logging_policy:Request URL: 'https://management.azure.com/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'x-ms-client-request-id': '23181adb-20fe-11ee-bb82-000d3ac5f120'
#     'User-Agent': 'azure-ai-ml/1.8.0 azsdk-python-mgmt-machinelearningservices/0.1.0 Python/3.11.4 (Windows-10-10.0.22621-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "GET /subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep?api-version=2022-05-01 HTTP/1.1" 200 None
# INFO:azure.core.pipeline.policies.http_logging_policy:Response status: 200
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'REDACTED'
#     'Expires': '-1'
#     'Vary': 'REDACTED'
#     'x-ms-request-id': 'c14850f4-93b7-400a-8ca2-3f2b89fe8258'
#     'x-ms-ratelimit-remaining-subscription-reads': '11995'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'x-ms-correlation-request-id': 'REDACTED'
#     'x-ms-routing-request-id': 'REDACTED'
#     'Date': 'Wed, 12 Jul 2023 21:51:09 GMT'
# DEBUG:azure.core.pipeline.policies._universal:Response status: '200'
# Response headers:
#     'Cache-Control': 'no-cache'
#     'Pragma': 'no-cache'
#     'Transfer-Encoding': 'chunked'
#     'Content-Type': 'application/json; charset=utf-8'
#     'Content-Encoding': 'gzip'
#     'Expires': '-1'
#     'Vary': 'Accept-Encoding,Accept-Encoding'
#     'x-ms-request-id': 'c14850f4-93b7-400a-8ca2-3f2b89fe8258'
#     'x-ms-ratelimit-remaining-subscription-reads': '11995'
#     'Request-Context': 'appId=cid-v1:2d2e8e63-272e-4b3c-8598-4ee570a0e70d'
#     'x-ms-response-type': 'standard'
#     'Strict-Transport-Security': 'max-age=31536000; includeSubDomains'
#     'X-Content-Type-Options': 'nosniff'
#     'x-aml-cluster': 'vienna-eastus2-01'
#     'x-request-time': '0.071'
#     'x-ms-correlation-request-id': 'c14850f4-93b7-400a-8ca2-3f2b89fe8258'
#     'x-ms-routing-request-id': 'WESTUS2:20230712T215109Z:c14850f4-93b7-400a-8ca2-3f2b89fe8258'
#     'Date': 'Wed, 12 Jul 2023 21:51:09 GMT'
# Response content:
# {
#   "id": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/batchEndpoints/bani-batch-4/deployments/bani-llama-dep",
#   "name": "bani-llama-dep",
#   "type": "Microsoft.MachineLearningServices/workspaces/batchEndpoints/deployments",
#   "properties": {
#     "description": null,
#     "properties": {},
#     "codeConfiguration": {
#       "codeId": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/codes/70db22b8-f570-4c8c-bc9b-d5dde19e36be/versions/1",
#       "scoringScript": "score_batch.py"
#     },
#     "environmentId": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/environments/for-llama-env/versions/1",
#     "environmentVariables": {
#       "MLFLOW_MODEL_FOLDER": "mlflow_model_folder",
#       "CONTENT_SAFETY_ENDPOINT": "aacs_endpoint",
#       "CONTENT_SAFETY_KEY": "aacs_access_key"
#     },
#     "compute": "/subscriptions/b17253fa-f327-42d6-9686-f3e553e24763/resourceGroups/bani-llm/providers/Microsoft.MachineLearningServices/workspaces/bani-llm-ws/computes/gpu-cluster",
#     "errorThreshold": -1,
#     "retrySettings": {
#       "maxRetries": 3,
#       "timeout": "PT50M"
#     },
#     "miniBatchSize": 1,
#     "loggingLevel": "Info",
#     "model": {
#       "referenceType": "Id",
#       "assetId": "azureml://registries/msft-meta-preview/models/Llama-2-7b/versions/6"
#     },
#     "maxConcurrencyPerInstance": 1,
#     "outputAction": "AppendRow",
#     "outputFileName": "predictions.csv",
#     "resources": {
#       "instanceCount": 1,
#       "instanceType": null,
#       "properties": null
#     },
#     "provisioningState": "Succeeded"
#   },
#   "systemData": {
#     "createdAt": "2023-07-12T17:25:19.3014602+00:00",
#     "createdBy": "Banibrata De",
#     "lastModifiedAt": "2023-07-12T21:50:38.3137505+00:00"
#   },
#   "tags": {},
#   "location": "eastus2"
# }
# ---Deployment created successfully---
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westus-0.in.applicationinsights.azure.com:443
# DEBUG:urllib3.connectionpool:https://westus-0.in.applicationinsights.azure.com:443 "POST //v2.1/track HTTP/1.1" 200 None

# %%
endpoint = ml_client.batch_endpoints.get(endpoint_name)
endpoint.defaults.deployment_name = deployment.name
ml_client.batch_endpoints.begin_create_or_update(endpoint).result()

# %% [markdown]
# ### 4. Test the Safety Enabled Llama batch endpoint.

# %%
data_path = "llama-files/data"
dataset_name = "summary-small"

summary_data = Data(
    path=data_path,
    type=AssetTypes.URI_FOLDER,
    description="A sample of the  dataset for text generation, in CSV file format",
    name=dataset_name,
)

# %%
summary_data = ml_client.data.create_or_update(summary_data)

# %%
from time import sleep

print(f"Waiting for data asset {dataset_name}", end="")
while not any(filter(lambda m: m.name == dataset_name, ml_client.data.list())):
    sleep(10)
    print(".", end="")

print(" [DONE]")

# %%
summary_data = ml_client.data.get(name=dataset_name, label="latest")

# %%
input = Input(type=AssetTypes.URI_FOLDER, path=summary_data.id)

# %%
import os
from azure.ai.ml.entities import BatchEndpoint
endpoint_name = "bani-batch-4"
# Check if the endpoint already exists in the workspace
try:
    endpoint = ml_client.batch_endpoints.get(endpoint_name)
    print("---Endpoint already exists---")
except:
    # Create an batch endpoint if it doesn't exist

    # Define the endpoint
    endpoint = BatchEndpoint(
        name=endpoint_name, description="Test endpoint for model"
    )

    # Trigger the endpoint creation
    try:
        ml_client.begin_create_or_update(endpoint).wait()
        print("\n---Endpoint created successfully---\n")
    except Exception as err:
        raise RuntimeError(
            f"Endpoint creation failed. Detailed Response:\n{err}"
        ) from err
deployment = ModelBatchDeployment(
    name=deployment_name,
    endpoint_name=endpoint.name,
    model=llama_model,
    environment=env,
    code_configuration=CodeConfiguration(
        code="llama-files/score",
        scoring_script="score_batch.py",
    ),
    compute=compute_name,
    environment_variables={
        "MLFLOW_MODEL_FOLDER": os.path.basename(llama_model.path),
        "CONTENT_SAFETY_ENDPOINT": aacs_endpoint,
        "CONTENT_SAFETY_KEY": aacs_access_key,
    },
    settings=ModelBatchDeploymentSettings(
        instance_count=1,
        max_concurrency_per_instance=1,
        mini_batch_size=1,
        output_action=BatchDeploymentOutputAction.APPEND_ROW,
        output_file_name="predictions.csv",
        retry_settings=BatchRetrySettings(max_retries=3, timeout=3000),
        logging_level="info",
    ),
)
# Trigger the deployment creation
try:
    ml_client.begin_create_or_update(deployment).wait()
    print("\n---Deployment created successfully---\n")
except Exception as err:
    raise RuntimeError(
        f"Deployment creation failed. Detailed Response:\n{err}"
    ) from err

endpoint = ml_client.batch_endpoints.get(endpoint_name)
endpoint.defaults.deployment_name = deployment.name
ml_client.batch_endpoints.begin_create_or_update(endpoint).result()

# %%
job = ml_client.batch_endpoints.invoke(endpoint_name=endpoint.name, input=input)

# %%
ml_client.batch_endpoints.begin_delete(endpoint.name).result()

# %%
ml_client.batch_deployments.get("bani-llama-dep", endpoint.name)
