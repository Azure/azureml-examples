# %% [markdown]
# # Script for converting Pascal VOC Object Detection labels to jsonl file

# %%
import json
import os
import xml.etree.ElementTree as ET

# %%
# Path to annotation file
data_dir = os.path.join("data", "odFridgeObjects") # path to images (local dir or azure data asset)
annotation_file = os.path.join(data_dir, "annotations_pascal.jsonl") # path to write annotation file
annotations_dir = os.path.join(data_dir, "annotations")
images_dir = os.path.join(data_dir, "images")

# %%
def pascal2jsonl(images_dir, annotation_file, annotations_dir):
    # Baseline of json line dictionary
    json_line_sample = {
        "image_url": images_dir,
        "image_details": {"format": None, "width": None, "height": None},
        "label": [],
    }

    with open(annotation_file, "w") as annotation_f:
        for i, filename in enumerate(os.listdir(annotations_dir)):
            if not filename.endswith(".xml"):
                print(f"Skipping unknown file: {filename}")
                continue

            annotation_filename = os.path.join(annotations_dir, filename)
            print(f"Parsing {annotation_filename}")

            root = ET.parse(annotation_filename).getroot()
            width = int(root.find("size/width").text)
            height = int(root.find("size/height").text)

            labels = []
            for object in root.findall("object"):
                name = object.find("name").text
                xmin = object.find("bndbox/xmin").text
                ymin = object.find("bndbox/ymin").text
                xmax = object.find("bndbox/xmax").text
                ymax = object.find("bndbox/ymax").text
                isCrowd = int(object.find("difficult").text)
                labels.append(
                    {
                        "label": name,
                        "topX": float(xmin) / width,
                        "topY": float(ymin) / height,
                        "bottomX": float(xmax) / width,
                        "bottomY": float(ymax) / height,
                        "isCrowd": isCrowd,
                    }
                )
            # build the jsonl file
            image_filename = root.find("filename").text
            _, file_extension = os.path.splitext(image_filename)
            json_line = dict(json_line_sample)
            json_line["image_url"] = os.path.join(json_line["image_url"],image_filename)
            json_line["image_details"]["format"] = file_extension[1:]
            json_line["image_details"]["width"] = width
            json_line["image_details"]["height"] = height
            json_line["label"] = labels

            annotation_f.write(json.dumps(json_line) + "\n")

# %%
pascal2jsonl(data_dir, annotation_file, annotations_dir)
# Out:
# Parsing data\odFridgeObjects\annotations\1.xml
# Parsing data\odFridgeObjects\annotations\10.xml
# Parsing data\odFridgeObjects\annotations\100.xml
# Parsing data\odFridgeObjects\annotations\101.xml
# Parsing data\odFridgeObjects\annotations\102.xml
# Parsing data\odFridgeObjects\annotations\103.xml
# Parsing data\odFridgeObjects\annotations\104.xml
# Parsing data\odFridgeObjects\annotations\105.xml
# Parsing data\odFridgeObjects\annotations\106.xml
# Parsing data\odFridgeObjects\annotations\107.xml
# Parsing data\odFridgeObjects\annotations\108.xml
# Parsing data\odFridgeObjects\annotations\109.xml
# Parsing data\odFridgeObjects\annotations\11.xml
# Parsing data\odFridgeObjects\annotations\110.xml
# Parsing data\odFridgeObjects\annotations\111.xml
# Parsing data\odFridgeObjects\annotations\112.xml
# Parsing data\odFridgeObjects\annotations\113.xml
# Parsing data\odFridgeObjects\annotations\114.xml
# Parsing data\odFridgeObjects\annotations\115.xml
# Parsing data\odFridgeObjects\annotations\116.xml
# Parsing data\odFridgeObjects\annotations\117.xml
# Parsing data\odFridgeObjects\annotations\118.xml
# Parsing data\odFridgeObjects\annotations\119.xml
# Parsing data\odFridgeObjects\annotations\12.xml
# Parsing data\odFridgeObjects\annotations\120.xml
# Parsing data\odFridgeObjects\annotations\121.xml
# Parsing data\odFridgeObjects\annotations\122.xml
# Parsing data\odFridgeObjects\annotations\123.xml
# Parsing data\odFridgeObjects\annotations\124.xml
# Parsing data\odFridgeObjects\annotations\125.xml
# Parsing data\odFridgeObjects\annotations\126.xml
# Parsing data\odFridgeObjects\annotations\127.xml
# Parsing data\odFridgeObjects\annotations\128.xml
# Parsing data\odFridgeObjects\annotations\13.xml
# Parsing data\odFridgeObjects\annotations\14.xml
# Parsing data\odFridgeObjects\annotations\15.xml
# Parsing data\odFridgeObjects\annotations\16.xml
# Parsing data\odFridgeObjects\annotations\17.xml
# Parsing data\odFridgeObjects\annotations\18.xml
# Parsing data\odFridgeObjects\annotations\19.xml
# Parsing data\odFridgeObjects\annotations\2.xml
# Parsing data\odFridgeObjects\annotations\20.xml
# Parsing data\odFridgeObjects\annotations\21.xml
# Parsing data\odFridgeObjects\annotations\22.xml
# Parsing data\odFridgeObjects\annotations\23.xml
# Parsing data\odFridgeObjects\annotations\24.xml
# Parsing data\odFridgeObjects\annotations\25.xml
# Parsing data\odFridgeObjects\annotations\26.xml
# Parsing data\odFridgeObjects\annotations\27.xml
# Parsing data\odFridgeObjects\annotations\28.xml
# Parsing data\odFridgeObjects\annotations\29.xml
# Parsing data\odFridgeObjects\annotations\3.xml
# Parsing data\odFridgeObjects\annotations\30.xml
# Parsing data\odFridgeObjects\annotations\31.xml
# Parsing data\odFridgeObjects\annotations\32.xml
# Parsing data\odFridgeObjects\annotations\33.xml
# Parsing data\odFridgeObjects\annotations\34.xml
# Parsing data\odFridgeObjects\annotations\35.xml
# Parsing data\odFridgeObjects\annotations\36.xml
# Parsing data\odFridgeObjects\annotations\37.xml
# Parsing data\odFridgeObjects\annotations\38.xml
# Parsing data\odFridgeObjects\annotations\39.xml
# Parsing data\odFridgeObjects\annotations\4.xml
# Parsing data\odFridgeObjects\annotations\40.xml
# Parsing data\odFridgeObjects\annotations\41.xml
# Parsing data\odFridgeObjects\annotations\42.xml
# Parsing data\odFridgeObjects\annotations\43.xml
# Parsing data\odFridgeObjects\annotations\44.xml
# Parsing data\odFridgeObjects\annotations\45.xml
# Parsing data\odFridgeObjects\annotations\46.xml
# Parsing data\odFridgeObjects\annotations\47.xml
# Parsing data\odFridgeObjects\annotations\48.xml
# Parsing data\odFridgeObjects\annotations\49.xml
# Parsing data\odFridgeObjects\annotations\5.xml
# Parsing data\odFridgeObjects\annotations\50.xml
# Parsing data\odFridgeObjects\annotations\51.xml
# Parsing data\odFridgeObjects\annotations\52.xml
# Parsing data\odFridgeObjects\annotations\53.xml
# Parsing data\odFridgeObjects\annotations\54.xml
# Parsing data\odFridgeObjects\annotations\55.xml
# Parsing data\odFridgeObjects\annotations\56.xml
# Parsing data\odFridgeObjects\annotations\57.xml
# Parsing data\odFridgeObjects\annotations\58.xml
# Parsing data\odFridgeObjects\annotations\59.xml
# Parsing data\odFridgeObjects\annotations\6.xml
# Parsing data\odFridgeObjects\annotations\60.xml
# Parsing data\odFridgeObjects\annotations\61.xml
# Parsing data\odFridgeObjects\annotations\62.xml
# Parsing data\odFridgeObjects\annotations\63.xml
# Parsing data\odFridgeObjects\annotations\64.xml
# Parsing data\odFridgeObjects\annotations\65.xml
# Parsing data\odFridgeObjects\annotations\66.xml
# Parsing data\odFridgeObjects\annotations\67.xml
# Parsing data\odFridgeObjects\annotations\68.xml
# Parsing data\odFridgeObjects\annotations\69.xml
# Parsing data\odFridgeObjects\annotations\7.xml
# Parsing data\odFridgeObjects\annotations\70.xml
# Parsing data\odFridgeObjects\annotations\71.xml
# Parsing data\odFridgeObjects\annotations\72.xml
# Parsing data\odFridgeObjects\annotations\73.xml
# Parsing data\odFridgeObjects\annotations\74.xml
# Parsing data\odFridgeObjects\annotations\75.xml
# Parsing data\odFridgeObjects\annotations\76.xml
# Parsing data\odFridgeObjects\annotations\77.xml
# Parsing data\odFridgeObjects\annotations\78.xml
# Parsing data\odFridgeObjects\annotations\79.xml
# Parsing data\odFridgeObjects\annotations\8.xml
# Parsing data\odFridgeObjects\annotations\80.xml
# Parsing data\odFridgeObjects\annotations\81.xml
# Parsing data\odFridgeObjects\annotations\82.xml
# Parsing data\odFridgeObjects\annotations\83.xml
# Parsing data\odFridgeObjects\annotations\84.xml
# Parsing data\odFridgeObjects\annotations\85.xml
# Parsing data\odFridgeObjects\annotations\86.xml
# Parsing data\odFridgeObjects\annotations\87.xml
# Parsing data\odFridgeObjects\annotations\88.xml
# Parsing data\odFridgeObjects\annotations\89.xml
# Parsing data\odFridgeObjects\annotations\9.xml
# Parsing data\odFridgeObjects\annotations\90.xml
# Parsing data\odFridgeObjects\annotations\91.xml
# Parsing data\odFridgeObjects\annotations\92.xml
# Parsing data\odFridgeObjects\annotations\93.xml
# Parsing data\odFridgeObjects\annotations\94.xml
# Parsing data\odFridgeObjects\annotations\95.xml
# Parsing data\odFridgeObjects\annotations\96.xml
# Parsing data\odFridgeObjects\annotations\97.xml
# Parsing data\odFridgeObjects\annotations\98.xml
# Parsing data\odFridgeObjects\annotations\99.xml
