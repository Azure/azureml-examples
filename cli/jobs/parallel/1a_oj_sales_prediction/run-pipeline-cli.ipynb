# %% [markdown]
# # Orange juice sales prediction example \[Paralle job\] \[Yaml + CLI example\]
#
# **Key notes for this example**
# - How to use **parallel job** for **many models training** scenario.
# - How to use parallel job **run_function** task with predefined **entry_script**.
# - How to pre-cook data into **mltable with partition setting**.
# - How to use **mltable** with **tabular data** as the **input of parallel job**.
# - How to use **partition_keys** in parallel job to consume data with partitions.
# - How to use **append_row_to** to aggregate returns to **uri_file** output.
# - How to use parallel job settings for many models training scenario:
#   - error_threshold
#   - mini_batch_error_threshold
#   - environment_variables
#
# To get the same example with python SDK experience, please refer to: [link]

# %% [markdown]
# # Upgrade to latest CLI

# %%
# !az --version
# Out:
# azure-cli                         2.30.0 *
#
# core                              2.30.0 *
# telemetry                          1.0.6 *
#
# Extensions:
# ml                          0.0.59051464
#
# Python location 'C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\python.exe'
# Extensions directory 'C:\Users\alainli\.azure\cliextensions'
#
# Python (Windows) 3.8.9 (tags/v3.8.9:a743f81, Apr  6 2021, 13:22:56) [MSC v.1928 32 bit (Intel)]
#
# Legal docs and information: aka.ms/AzureCliLegal
# WARNING: You have 3 updates available. Consider updating your CLI installation with 'az upgrade'
#
# Please let us know how we are doing: https://aka.ms/azureclihats
# and let us know if you're interested in trying out our newest features: https://aka.ms/CLIUXstudy

# %%
# !az extension list
# Out:
# [
#   {
#     "experimental": false,
#     "extensionType": "whl",
#     "name": "ml",
#     "path": "C:\\Users\\alainli\\.azure\\cliextensions\\ml",
#     "preview": true,
#     "version": "0.0.59051464"
#   }
# ]

# %%
# Install azure ml extension if there has no such extension in the list
# !az extension add -n ml -y
# Out:
# WARNING: Extension 'ml' is already installed.

# %%
# Upgrade ml extension
# !az extension update -n ml

# %% [markdown]
# # Login to Azure CLI

# %%
# !az login
# Out:
# WARNING: The default web browser has been opened at https://login.microsoftonline.com/organizations/oauth2/v2.0/authorize. Please continue the login in the web browser. If no web browser is available or if the web browser fails to open, use device code flow with `az login --use-device-code`.
# cannot import name 'DeserializationError' from 'azure.core.exceptions' (C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\lib\site-packages\azure\core\exceptions.pyc)
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bfd9f30e-252d-4fc8-823c-f27d994fc8b7",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "balapv-aml-sub",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b17253fa-f327-42d6-9686-f3e553e24763",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Data Science VM Team",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b8c23406-f9b5-4ccb-8a65-a8cb5dcd6a5a",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       },
#       {
#         "tenantId": "f40b18ba-b66c-49e4-9fd8-4fc7d3d19f0f"
#       }
#     ],
#     "name": "Aether3P Dev",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ad203158-bc5d-4e72-b764-2607833a71dc",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Project Vienna Build",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b6dc87f3-c479-49c8-8cb5-7896da3ff895",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ICE-ML-Dev",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ae71ef11-a03f-4b4f-a0e6-ef144727c711",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Bing MM Measurement",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a1ffc958-d2c7-493e-9f1e-125a0477f536",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSFT
01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e4e06275-58d1-4081-8f1b-be12462eb701",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "CSR-CUSPOC-MST-Hiramfleitas",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "3cd95ff9-ac62-4b5c-8240-0cd046687ea0",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Internal App Insights Resources for Perflens",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bbe41737-1ade-44df-8e33-217f11b8b452",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Service Profiler Development",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "1163fbbe-27e7-4b0f-8466-195fe5417043",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       },
#       {
#         "tenantId": "d0ecd01b-d782-448e-bae0-c3cad0e0543a"
#       },
#       {
#         "tenantId": "94c4857e-1130-4ab8-8eac-069b40c9db20"
#       },
#       {
#         "tenantId": "f702a9dc-ae48-4dc7-8f0a-8155a6dfa4e5"
#       }
#     ],
#     "name": "Python_AI_Tools_PM_Team_Sub",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8ae1955e-f748-4273-a507-10159ba940f9",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "SPO-CyrusB",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9b4236fe-df75-4289-bf00-40628ed41fd9",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Customer Confidence Proof of Concepts",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "a5f9f0d3-a937-4de5-8cf3-387fce51e80c",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "anguil",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "13723929-6644-4060-a50a-cc38ebc5e8b1",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "LinuxMdsd Test",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "10d0b7c6-9243-4713-91a9-2730375d3a1b",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ASutton Subscription",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "9372b318-ed3a-4504-95a6-941201300f78",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "OE-Service Management Platform - External - Prod",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e0fd569c-e34a-4249-8c24-e8d723c7f054",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AML - Responsible AI R&D",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "56207a5d-4746-4a2d-9f7f-c5ac77a5ddfd",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "Traffic manager Preview",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "bac044cf-49e1-4843-8dda-1ce9662606c8",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "UI Fabric",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ca38bc19-cf50-48e2-bbe6-8c35b40212d8",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Maps Mining Azure",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b2a328a7-ffff-4c09-b643-a4758cf170bc",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AISC-DEV-02",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "85b3dbca-5974-4067-9669-67a141095a76",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "027fe226-784c-4798-a157-5e0e7893424d"
#       }
#     ],
#     "name": "Terraform Testing on Azure with TTL = 2 Days",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "8cff5d56-95fb-4a74-ab9d-079edb45313e",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "cdc5aeea-15c5-4db6-b079-fcadd2505dc2"
#       }
#     ],
#     "name": "Skype-NetEM-STAGING",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "68f3658f-0090-4277-a500-f02227aaee97",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "zejunz",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "79f57c16-00fe-48da-87d4-5192e86cd047",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "TScienceGPU",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eec2de82-6ab2-4a84-ae5f-57e9a10bf661",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ServicesPortfolio MCS",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "e72e5254-f265-4e95-9bd2-9ee8e7329051",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Speech Services - DEV - SDK (rob)",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "eef8b6d5-94da-4b36-9327-a662f2674efb",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "AISC-EngSys-01",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "d2c9544f-4329-4642-b73d-020e7fef844f",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "HPCScrub1",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b01d3783-f526-474f-9c46-19c1080fdb7b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Xap - Production Tools",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "38d911df-2706-4195-8563-c75b49f7a88d",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Actions on AKS Dev",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "de6bc98d-2a4d-4607-919e-67692d1eba2b",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Dart Eng Beta",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "b8faf5eb-39a1-42c4-9e2a-335704d4c740",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "VSO-SD-POC",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "f0d19b89-f606-48fe-b2b0-c8259f8f25b6",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AzDev_RASP_Eng",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "35da7c97-a5de-4be6-b1f0-69d33722a3f4",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "ServiceInsights_Eng",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "21057343-6652-448d-8422-d7dadedf1f11",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "VSO DevTest Secrets",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "96aede12-2f73-41cb-b983-6d11a904839b",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML - Pipelines R&D",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "22da88f6-1210-4de2-a5a3-da4c7c2a1213",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "Singularity Shared",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "15ae9cb6-95c1-483d-a0e3-b1a1a3b06324",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AzureML Nursery",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "4c6dcd0e-1a79-4f3c-9bf2-c920ac31cead",
#     "isDefault": false,
#     "managedByTenants": [],
#     "name": "MSR TAPP",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "ea4faa5b-5e44-4236-91f6-5483d5b17d14",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "f40b18ba-b66c-49e4-9fd8-4fc7d3d19f0f"
#       },
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       }
#     ],
#     "name": "AML - Inferencing R&D Personal",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "id": "442d0207-a601-43dd-b9b8-856350b609d7",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "2f4a9838-26b7-47ee-be60-ccc1fdec5953"
#       },
#       {
#         "tenantId": "d0ecd01b-d782-448e-bae0-c3cad0e0543a"
#       },
#       {
#         "tenantId": "94c4857e-1130-4ab8-8eac-069b40c9db20"
#       }
#     ],
#     "name": "Main MS Internal - Mutlu",
#     "state": "Enabled",
#     "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "user": {
#       "name": "alainli@microsoft.com",
#       "type": "user"
#     }
#   }
# ]

# %% [markdown]
# # Configure default workspace.

# %%
# !az account set -s "__your sub id__"
# !az configure --defaults group={__your resource group name__} workspace={__your workspace name__} location={__your workspace region__}

# %% [markdown]
# # Submit pipeline to default workspace

# %%
# Submit pipeline job to default workspace
# !az ml job create --file pipeline.yml
# Out:
# cannot import name 'DeserializationError' from 'azure.core.exceptions' (C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\lib\site-packages\azure\core\exceptions.pyc)
# ERROR: 'ml' is misspelled or not recognized by the system.
#
# Examples from AI knowledge base:
# az extension add --name anextension
# Add extension by name
#
# az extension list-available
# List all publicly available extensions
#
# https://docs.microsoft.com/en-US/cli/azure/extension#az_extension_add
# Read more about the command in reference docs

# %%
# Submit pipeline job to specific workspace
# !az ml job create --file pipeline.yml --resource-group __your-resource-group__ --workspace-name __your-workspace__

# %%
# You can override the pipeline run properties by using 'set' parameter
# !az ml job create --file pipeline.yml --set jobs.partition_job.inputs.partition_keys="Store,Brand" jobs.partition_job.resources.instance_count=3
# Out:
# cannot import name 'DeserializationError' from 'azure.core.exceptions' (C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\lib\site-packages\azure\core\exceptions.pyc)
# ERROR: 'ml' is misspelled or not recognized by the system.
#
# Examples from AI knowledge base:
# az extension add --name anextension
# Add extension by name
#
# az extension list-available
# List all publicly available extensions
#
# https://docs.microsoft.com/en-US/cli/azure/extension#az_extension_add
# Read more about the command in reference docs
